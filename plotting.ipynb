# %%
import numpy as np
import pandas as pd
import visualization as vis
import importlib
importlib.reload(vis)
# Out:
# <module 'visualization' from '/Users/goldfei/Documents/IsoLearner-GUI/visualization.py'>

# %%
data= pd.read_csv('/Users/goldfei/Documents/IsoLearner-GUI/uploads/glucose-KD-M1-isotopolouges-ranks.csv')

# %%
vis.plot_brain(data,iso_name="Taurodeoxycholic acid m+25")
